# %%
import numpy as np
import pandas as pd
from scipy.optimize import nnls
import matplotlib.pyplot as plt

from StateData import StateData

# %%
State_Names = ['Vermont','Wyoming','California','California Simulated']

Policy_types = ['No_Intervention','All_policies','Case_Isolation','Household_Quarantine',\
                'Place_Closure','Social_Distancing']

# %% [markdown]
# ### Objective
# We are working with actual california dataset generated using UK group's model
# 1. We are calculating A matrix parameters for different phases. <br>
# 2. We have to find difference between these A matrices <br>

# %%
state_name = State_Names[2]

Cal_data = StateData(state_name)

# %% [markdown]
# We got <b>Cal_data</b> object by using StateData class. <br>
# We get values of following 4 variables from the object <br>
# <br>
# <b>orig_beta_data</b> : daywise cummulative number of infected cases for different age groups<br>
# <b>S_0</b> : Initial susceptible number of people for each age group <br>
# <b>population</b> : Total population <br>
# <b>CA_test_df</b> : daily total number of tests<br>

# %%
orig_beta_data = Cal_data.orig_beta_data
column_names = Cal_data.column_names
S_0 = Cal_data.S_0
population = Cal_data.population
CA_test_df = Cal_data.CA_test_df

# %%
orig_beta_data
# Out:
#        0-17    18-49   50-64     65+
# 0       120     5302    2879    2342
# 1       137     5917    3253    2660
# 2       160     6610    3653    2966
# 3       173     7099    3884    3129
# 4       197     7753    4344    3516
# ..      ...      ...     ...     ...
# 332  447354  1993740  664406  371427
# 333  447770  1995109  664879  371704
# 334  448193  1996925  665595  372106
# 335  448653  1998780  666332  372554
# 336  449313  2001313  667234  373112
#
# [337 rows x 4 columns]

# %%
orig_beta_data = pd.DataFrame(orig_beta_data, columns = column_names)

# %%
print(S_0) 
print(population)
# Out:
# [10786836 19139720  5397369  4188295]
# 39512223

# %%
print(CA_test_df)
# Out:
#            date    tested
# 0    2020-03-18      6291
# 1    2020-03-19     11487
# 2    2020-03-20     12528
# 3    2020-03-21     13467
# 4    2020-03-22     14317
# ..          ...       ...
# 347  2021-02-28  48712676
# 348  2021-03-01  48897190
# 349  2021-03-02  49028048
# 350  2021-03-03  49147685
# 351  2021-03-04  49294503
#
# [352 rows x 2 columns]

# %% [markdown]
# For california simulated dataset, we don't have daily number of test data

# %%
plt.plot(orig_beta_data)
plt.legend(orig_beta_data.columns)
plt.title('Orig Data')
# Out:
# Text(0.5, 1.0, 'Orig Data')

# %% [markdown]
# ### SIR data generation from 'orig_beta_data' and visualization

# %% [markdown]
# We are considering recovery time <b>T_R = 5</b> days for calculating S_data, beta_data and R_data from orig_beta_data

# %%
T_R = 5

# %%
R_data = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
R_data = R_data.rename(columns = lambda x: 'R'+ x)

R_data.values[T_R:,:] = orig_beta_data.values[:-T_R,:]

R_data_tilde = R_data/S_0


beta_data_tilde = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
beta_data_tilde = beta_data_tilde.rename(columns = lambda x: 'I'+ x)

old_beta_data_tilde = orig_beta_data/S_0

beta_data_tilde.values[:,:] = old_beta_data_tilde.values - R_data_tilde.values


S_data_tilde = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
S_data_tilde = S_data_tilde.rename(columns = lambda x: 'S'+ x)

S_data_tilde.values[:,:] = 1- beta_data_tilde.values - R_data_tilde.values

# %%
fig, axes = plt.subplots(nrows=4,ncols=2, figsize = (18,15))

axes[0,0].plot(R_data_tilde)
axes[0,0].set_title('R data')

axes[0,1].plot(R_data_tilde.diff().fillna(0))
axes[0,1].set_title('R first diff')

axes[1,0].plot(beta_data_tilde)
axes[1,0].set_title('Beta Data')

axes[1,1].plot(beta_data_tilde.diff().fillna(0))
axes[1,1].set_title('Beta first diff')

axes[2,0].plot(S_data_tilde)
axes[2,0].set_title('S Data')

axes[2,1].plot(S_data_tilde.diff().fillna(0))
axes[2,1].set_title('S first diff')

axes[3,0].plot(orig_beta_data)
axes[3,0].legend(orig_beta_data.columns)
axes[3,0].set_title('Orig Data')

axes[3,1].plot(orig_beta_data.diff().fillna(0))
axes[3,1].set_title('Orig first diff')
# Out:
# Text(0.5, 1.0, 'Orig first diff')

# %% [markdown]
# We need to smoothen these curves.

# %%
window_length = 15

dataframe = orig_beta_data
first_diff = dataframe.diff().fillna(0)
smoothened_first_diff = first_diff.rolling(window_length,min_periods=1).mean()
smoothened_first_diff.iloc[0] = dataframe.iloc[0]
smoothened_final_data = smoothened_first_diff.cumsum()

#smoothened_final_data = orig_beta_data

R_data = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
R_data = R_data.rename(columns = lambda x: 'R'+ x)

R_data.values[T_R:,:] = smoothened_final_data.values[:-T_R,:]

R_data_tilde = R_data/S_0


beta_data_tilde = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
beta_data_tilde = beta_data_tilde.rename(columns = lambda x: 'I'+ x)

old_beta_data_tilde = smoothened_final_data/S_0

beta_data_tilde.values[:,:] = old_beta_data_tilde.values - R_data_tilde.values


S_data_tilde = pd.DataFrame().reindex_like(orig_beta_data).fillna(0)
S_data_tilde = S_data_tilde.rename(columns = lambda x: 'S'+ x)

S_data_tilde.values[:,:] = 1- beta_data_tilde.values - R_data_tilde.values

# %%
fig, axes = plt.subplots(nrows=4,ncols=2, figsize = (18,15))

axes[0,0].plot(R_data_tilde)
axes[0,0].set_title('R data')

axes[0,1].plot(R_data_tilde.diff().fillna(0))
axes[0,1].set_title('R first diff')

axes[1,0].plot(beta_data_tilde)
axes[1,0].set_title('Beta Data')

axes[1,1].plot(beta_data_tilde.diff().fillna(0))
axes[1,1].set_title('Beta first diff')

axes[2,0].plot(S_data_tilde)
axes[2,0].set_title('S Data')

axes[2,1].plot(S_data_tilde.diff().fillna(0))
axes[2,1].set_title('S first diff')

axes[3,0].plot(orig_beta_data)
axes[3,0].legend(smoothened_final_data.columns)
axes[3,0].set_title('Orig Data')

axes[3,1].plot(smoothened_final_data.diff().fillna(0))
axes[3,1].set_title('Orig first diff')
# Out:
# Text(0.5, 1.0, 'Orig first diff')

# %% [markdown]
# We can see, smoothed data is looks good and we can use this data for parameter estimation and SIR data generation

# %% [markdown]
# ## Parameter estimation, SIR data and loss/error generation

# %% [markdown]
# Define phases to be considered:

# %%
phase_1 = range(0,65)
phase_2 = range(65,105)
phase_3 = range(105,175)
phase_4 = range(175,orig_beta_data.shape[0])
phases = [phase_1,phase_2,phase_3,phase_4]

# %%
param_loss_tr_dict_multiplication_fact = {}

factor_range = range(1,2,1)
T_R_range = range(1,25,1)

### This window length is for smoothening actual california data
window_length = 15
### we don't need this in case of simulated data for any state

for factor in factor_range:
    
    dataframe = orig_beta_data * factor
    param_loss_tr_dict = {}

    for T_R in T_R_range:
        
        #################################################################################
        ## We are calling SIR_Data_with_T_R function in object created by StateData class 
        ## to get S,I,R dataframes 
        
        S_data, beta_data, R_data = Cal_data.SIR_Data_with_T_R(orig_beta_data,
                                                               T_R, 
                                                               S_0, 
                                                               population,
                                                               smoothing = True, 
                                                               undetected_fact = False, 
                                                               window_length = window_length )
        
        #################################################################################
        ## We are calling get_params_and_generated_data function in object created by StateData class 
        ## to get parameters and generated data 
        
        A_No_int_nn_list, Gamma_nn_list, S_data_gen, beta_data_gen, R_data_gen \
                = Cal_data.get_params_and_generated_data(S_data, 
                                                         beta_data, 
                                                         R_data, 
                                                         phases, T_R)
        
        #################################################################################
        ## We are using sum of square of differences as our loss
        
        loss_S_data =  np.sum((S_data.iloc[T_R+1:].values - S_data_gen.iloc[T_R+1:].values)**2)/factor**2
        loss_beta_data =  np.sum((beta_data.iloc[T_R+1:].values - beta_data_gen.iloc[T_R+1:].values)**2)/factor**2
        loss_R_data =  np.sum((R_data.iloc[T_R+1:].values - R_data_gen.iloc[T_R+1:].values)**2)/factor**2
        
        loss = loss_S_data + loss_beta_data +loss_R_data
        
        #################################################################################
        ## Printitng losses 
        
        print('loss for '+str(T_R)+' days of recovery and multiplication factor is '+str(factor))
        print('loss is '+str(loss))
        print('S_data loss is '+str(loss_S_data))
        print('beta_data loss is '+str(loss_beta_data))
        print('R_data loss is '+str(loss_R_data))
        print('\n')
        
        #################################################################################
        ## Storing initial data, parameters, generated data and losses for given T_R in a dictionary
        
        param_loss_tr_dict[T_R] = {
                                    'A_No_int_nn':A_No_int_nn_list,
                                   'Gamma_nn':Gamma_nn_list,
                                   
                                   'loss':loss,
                                   'loss_S_data':loss_S_data,
                                   'loss_beta_data':loss_beta_data,
                                   'loss_R_data':loss_R_data,
                                   
                                   'S_data':S_data,
                                   'beta_data':beta_data,
                                   'R_data':R_data,
                                   
                                   'S_data_gen':S_data_gen,
                                   'beta_data_gen':beta_data_gen,
                                   'R_data_gen':R_data_gen
                                  }
    
    #################################################################################
    ## Storing dictionary generated for given factor value
    param_loss_tr_dict_multiplication_fact[factor] = param_loss_tr_dict
# Out:
# start_date, end_date for a phase
# 2 64
# Max, Min in A matrix
# 9.461624665895297 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 8.783384230198577 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 9.158593452321504 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 8.191860681916866 0.0
# loss for 1 days of recovery and multiplication factor is 1
# loss is 2.0214641850662992e-05
# S_data loss is 1.0408788867942702e-05
# beta_data loss is 2.994957374765804e-08
# R_data loss is 9.77590340897263e-06
#
#
# start_date, end_date for a phase
# 3 64
# Max, Min in A matrix
# 4.74069710425038 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 3.914798688982704 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 3.9235165814348916 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 2.651315616761219 0.0
# loss for 2 days of recovery and multiplication factor is 1
# loss is 2.7724156003953612e-05
# S_data loss is 1.4315801374209451e-05
# beta_data loss is 1.2651220691009407e-07
# R_data loss is 1.3281842422834069e-05
#
#
# start_date, end_date for a phase
# 4 64
# Max, Min in A matrix
# 3.1674864971452905 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 2.345005603720595 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 2.162015683135167 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.606936769430557 0.0
# loss for 3 days of recovery and multiplication factor is 1
# loss is 2.72172018064152e-05
# S_data loss is 1.4073160723271713e-05
# beta_data loss is 2.774799011577978e-07
# R_data loss is 1.286656118198569e-05
#
#
# start_date, end_date for a phase
# 5 64
# Max, Min in A matrix
# 2.3783418483908716 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.6901728512964604 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 1.2818725668613455 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.6640705604594384 0.0
# loss for 4 days of recovery and multiplication factor is 1
# loss is 3.12021365981078e-05
# S_data loss is 1.6084378067246733e-05
# beta_data loss is 4.999155284758947e-07
# R_data loss is 1.4617843002385172e-05
#
#
# start_date, end_date for a phase
# 6 64
# Max, Min in A matrix
# 1.9049586447219047 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.733097184994882 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.7568476144369394 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.8131495763556051 0.0
# loss for 5 days of recovery and multiplication factor is 1
# loss is 3.412716394083956e-05
# S_data loss is 1.7547419474820076e-05
# beta_data loss is 8.013171154956833e-07
# R_data loss is 1.5778427350523808e-05
#
#
# start_date, end_date for a phase
# 7 64
# Max, Min in A matrix
# 1.5888893871729841 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.7469554921500299 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.5492941257513877 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.8844749621863774 0.0
# loss for 6 days of recovery and multiplication factor is 1
# loss is 3.981613221157878e-05
# S_data loss is 2.0467834150650495e-05
# beta_data loss is 1.2186836760322471e-06
# R_data loss is 1.812961438489604e-05
#
#
# start_date, end_date for a phase
# 8 64
# Max, Min in A matrix
# 1.3630222198002757 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.5945693603593103 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.5251481043008689 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.6238753019677876 0.0
# loss for 7 days of recovery and multiplication factor is 1
# loss is 4.527208913502501e-05
# S_data loss is 2.323866836022311e-05
# beta_data loss is 1.7318397679804637e-06
# R_data loss is 2.0301581006821434e-05
#
#
# start_date, end_date for a phase
# 9 64
# Max, Min in A matrix
# 1.1938133973442124 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.358684103734824 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.49645144322248036 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.4280793179830564 0.0
# loss for 8 days of recovery and multiplication factor is 1
# loss is 5.184887914356723e-05
# S_data loss is 2.6631612462226703e-05
# beta_data loss is 2.4010135228418793e-06
# R_data loss is 2.281625315849865e-05
#
#
# start_date, end_date for a phase
# 10 64
# Max, Min in A matrix
# 1.0619532700488958 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.1893880887265318 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.36363260005289305 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.2755128616811908 0.0
# loss for 9 days of recovery and multiplication factor is 1
# loss is 5.913922316322826e-05
# S_data loss is 3.039806308842332e-05
# beta_data loss is 3.1715967293121394e-06
# R_data loss is 2.55695633454928e-05
#
#
# start_date, end_date for a phase
# 11 64
# Max, Min in A matrix
# 0.956832229709905 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 1.032542559963497 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.23584737455801386 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.1531536827063047 0.0
# loss for 10 days of recovery and multiplication factor is 1
# loss is 6.442543615720556e-05
# S_data loss is 3.30722432284943e-05
# beta_data loss is 4.086774221734717e-06
# R_data loss is 2.7266418706976544e-05
#
#
# start_date, end_date for a phase
# 12 64
# Max, Min in A matrix
# 0.8706885932938778 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.9169900752654663 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.1944007949844009 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 1.0527705302443786 0.0
# loss for 11 days of recovery and multiplication factor is 1
# loss is 7.25037534979913e-05
# S_data loss is 3.7239007470486605e-05
# beta_data loss is 5.180221194743939e-06
# R_data loss is 3.0084524832760763e-05
#
#
# start_date, end_date for a phase
# 13 64
# Max, Min in A matrix
# 0.7988261666343276 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.7977155360918318 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.1777673903305271 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.968849235563593 0.0
# loss for 12 days of recovery and multiplication factor is 1
# loss is 8.004498093048195e-05
# S_data loss is 4.1097811054493344e-05
# beta_data loss is 6.490415082404024e-06
# R_data loss is 3.2456754793584584e-05
#
#
# start_date, end_date for a phase
# 14 64
# Max, Min in A matrix
# 0.7375911269046845 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.6718360270532729 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.16372724401179267 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.8975214828719384 0.0
# loss for 13 days of recovery and multiplication factor is 1
# loss is 9.072313664075828e-05
# S_data loss is 4.6699142312701474e-05
# beta_data loss is 8.096073490424148e-06
# R_data loss is 3.5927920837632664e-05
#
#
# start_date, end_date for a phase
# 15 64
# Max, Min in A matrix
# 0.6850707505015418 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.5535726974705393 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.1517195014796369 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.8360950146912859 0.0
# loss for 14 days of recovery and multiplication factor is 1
# loss is 0.00010076447392097726
# S_data loss is 5.1935337686776e-05
# beta_data loss is 9.816590130044627e-06
# R_data loss is 3.9012546104156625e-05
#
#
# start_date, end_date for a phase
# 16 64
# Max, Min in A matrix
# 0.6388780603845937 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.441436525185083 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.14133785068836496 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.7825827125342028 0.0
# loss for 15 days of recovery and multiplication factor is 1
# loss is 0.00011092458101496746
# S_data loss is 5.723215857447846e-05
# beta_data loss is 1.1754622669124928e-05
# R_data loss is 4.1937799771364066e-05
#
#
# start_date, end_date for a phase
# 17 64
# Max, Min in A matrix
# 0.5984916469375937 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.36183672904416486 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.1322776433221374 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.7354870109578426 0.0
# loss for 16 days of recovery and multiplication factor is 1
# loss is 0.00012166816223245782
# S_data loss is 6.285165904979714e-05
# beta_data loss is 1.3803771918930605e-05
# R_data loss is 4.5012731263730066e-05
#
#
# start_date, end_date for a phase
# 18 64
# Max, Min in A matrix
# 0.5631387370729984 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.2973831862328674 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.12431011124939821 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.6936423004156245 0.0
# loss for 17 days of recovery and multiplication factor is 1
# loss is 0.000132789231485774
# S_data loss is 6.864016927069478e-05
# beta_data loss is 1.6070833987425052e-05
# R_data loss is 4.807822822765418e-05
#
#
# start_date, end_date for a phase
# 19 64
# Max, Min in A matrix
# 0.5313736936616654 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.26462544901441426 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.1172500971269149 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.6561626096403003 0.0
# loss for 18 days of recovery and multiplication factor is 1
# loss is 0.0001466808030375601
# S_data loss is 7.60329244399459e-05
# beta_data loss is 1.8790226882687606e-05
# R_data loss is 5.185765171492661e-05
#
#
# start_date, end_date for a phase
# 20 64
# Max, Min in A matrix
# 0.5030190651666044 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.2525032971759514 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.11095310485145254 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.6223698104281824 0.0
# loss for 19 days of recovery and multiplication factor is 1
# loss is 0.00016182304133579488
# S_data loss is 8.416779386743855e-05
# beta_data loss is 2.198915051390473e-05
# R_data loss is 5.56660969544516e-05
#
#
# start_date, end_date for a phase
# 21 64
# Max, Min in A matrix
# 0.4773204503050591 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.2434835460117906 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.10530031150374335 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.5916607553205242 0.0
# loss for 20 days of recovery and multiplication factor is 1
# loss is 0.00017772328518642338
# S_data loss is 9.282521092995011e-05
# beta_data loss is 2.5519791508560785e-05
# R_data loss is 5.937828274791247e-05
#
#
# start_date, end_date for a phase
# 22 64
# Max, Min in A matrix
# 0.4539015768329074 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.2353406519047742 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.10019879747663399 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.5635597940825664 0.0
# loss for 21 days of recovery and multiplication factor is 1
# loss is 0.0001928181046380694
# S_data loss is 0.00010103417780320874
# beta_data loss is 2.9302877713802356e-05
# R_data loss is 6.24810491210583e-05
#
#
# start_date, end_date for a phase
# 23 64
# Max, Min in A matrix
# 0.4323914627346489 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.22796187474895072 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.09557113916033527 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.5377166244097105 0.0
# loss for 22 days of recovery and multiplication factor is 1
# loss is 0.00020857323765991192
# S_data loss is 0.00010967355231538461
# beta_data loss is 3.346847108392063e-05
# R_data loss is 6.543121426060666e-05
#
#
# start_date, end_date for a phase
# 24 64
# Max, Min in A matrix
# 0.412722663993296 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.21863805996517574 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.09135430348265236 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.5138303201340363 0.0
# loss for 23 days of recovery and multiplication factor is 1
# loss is 0.0002241321623539075
# S_data loss is 0.00011826152031266605
# beta_data loss is 3.7849752457078935e-05
# R_data loss is 6.80208895841625e-05
#
#
# start_date, end_date for a phase
# 25 64
# Max, Min in A matrix
# 0.3947273536397895 0.0
# start_date, end_date for a phase
# 65 104
# Max, Min in A matrix
# 0.2084612405945621 0.0
# start_date, end_date for a phase
# 105 174
# Max, Min in A matrix
# 0.08749661513561395 0.0
# start_date, end_date for a phase
# 175 223
# Max, Min in A matrix
# 0.49164538950769976 0.0
# loss for 24 days of recovery and multiplication factor is 1
# loss is 0.0002398183066204211
# S_data loss is 0.00012691758701470927
# beta_data loss is 4.256755221144212e-05
# R_data loss is 7.03331673942697e-05

# %%
key_to_minimize = 'loss'
min_factor = 1
min_index = 0
min_loss = 0
count = 0
for key in param_loss_tr_dict_multiplication_fact.keys():
    param_loss_tr_dict = param_loss_tr_dict_multiplication_fact[key]
    for i in param_loss_tr_dict.keys():
        print(key, i, param_loss_tr_dict[i][key_to_minimize], param_loss_tr_dict[i]['loss_S_data'])
        if(count == 0):
            min_loss = param_loss_tr_dict[i][key_to_minimize]
            min_index=i
            min_factor = key
            count+=1
        elif(param_loss_tr_dict[i][key_to_minimize]<min_loss):
            min_loss = param_loss_tr_dict[i][key_to_minimize]
            min_index = i
            min_factor = key

print("\n")
print("Mul_factor, Recovery time, Overall loss")
print(min_factor, min_index, min_loss)
# Out:
# 1 1 2.0214641850662992e-05 1.0408788867942702e-05
# 1 2 2.7724156003953612e-05 1.4315801374209451e-05
# 1 3 2.72172018064152e-05 1.4073160723271713e-05
# 1 4 3.12021365981078e-05 1.6084378067246733e-05
# 1 5 3.412716394083956e-05 1.7547419474820076e-05
# 1 6 3.981613221157878e-05 2.0467834150650495e-05
# 1 7 4.527208913502501e-05 2.323866836022311e-05
# 1 8 5.184887914356723e-05 2.6631612462226703e-05
# 1 9 5.913922316322826e-05 3.039806308842332e-05
# 1 10 6.442543615720556e-05 3.30722432284943e-05
# 1 11 7.25037534979913e-05 3.7239007470486605e-05
# 1 12 8.004498093048195e-05 4.1097811054493344e-05
# 1 13 9.072313664075828e-05 4.6699142312701474e-05
# 1 14 0.00010076447392097726 5.1935337686776e-05
# 1 15 0.00011092458101496746 5.723215857447846e-05
# 1 16 0.00012166816223245782 6.285165904979714e-05
# 1 17 0.000132789231485774 6.864016927069478e-05
# 1 18 0.0001466808030375601 7.60329244399459e-05
# 1 19 0.00016182304133579488 8.416779386743855e-05
# 1 20 0.00017772328518642338 9.282521092995011e-05
# 1 21 0.0001928181046380694 0.00010103417780320874
# 1 22 0.00020857323765991192 0.00010967355231538461
# 1 23 0.0002241321623539075 0.00011826152031266605
# 1 24 0.0002398183066204211 0.00012691758701470927
#
#
# Mul_factor, Recovery time, Overall loss
# 1 1 2.0214641850662992e-05

# %% [markdown]
# Exploring in the data that we saved above, we found out that we have minimum overall loss for multiplication factor 1 and recovery time 4 days.

# %% [markdown]
# #### Visualizing data generated by age-structured SIR model with respect to base data

# %%
param_loss_tr_dict = param_loss_tr_dict_multiplication_fact[min_factor]

# %%
####### Getting beta_data and beta_data_gen for minimum loss

beta_data_min_loss = param_loss_tr_dict[min_index]['beta_data']
beta_data_gen_min_loss = param_loss_tr_dict[min_index]['beta_data_gen']

beta_data_min_loss = beta_data_min_loss*population
beta_data_gen_min_loss = beta_data_gen_min_loss*population

beta_data_min_loss = beta_data_min_loss.astype('int64')
beta_data_gen_min_loss = beta_data_gen_min_loss.astype('int64')

####### Getting S_data and S_data_gen for minimum loss

S_data_min_loss = param_loss_tr_dict[min_index]['S_data']
S_data_gen_min_loss = param_loss_tr_dict[min_index]['S_data_gen']

S_data_min_loss = S_data_min_loss*population
S_data_gen_min_loss = S_data_gen_min_loss*population

S_data_min_loss = S_data_min_loss.astype('int64')
S_data_gen_min_loss = S_data_gen_min_loss.astype('int64')

####### Getting R_data and R_data_gen for minimum loss

R_data_min_loss = param_loss_tr_dict[min_index]['R_data']
R_data_gen_min_loss = param_loss_tr_dict[min_index]['R_data_gen']

R_data_min_loss = R_data_min_loss*population
R_data_gen_min_loss = R_data_gen_min_loss*population

R_data_min_loss = R_data_min_loss.astype('int64')
R_data_gen_min_loss = R_data_gen_min_loss.astype('int64')

# %%
start_date = min_index + 1
phase = range(start_date,phases[-1][-1])
phase
# Out:
# range(2, 223)

# %%
set_of_age_groups = column_names

for age_group in  set_of_age_groups:

    fig, ax = plt.subplots(1,3,figsize=(15,5))

    ax[0].plot(S_data_min_loss['S'+age_group].iloc[phase],label='Original')
    ax[0].plot(S_data_gen_min_loss['S'+age_group].iloc[phase], label='Generated')
    ax[0].legend()
    ax[0].grid(True)
    ax[0].set_title('Susceptible, age '+ age_group+", "+state_name)

    ax[1].plot(beta_data_min_loss['I'+age_group].iloc[phase],label='Original')
    ax[1].plot(beta_data_gen_min_loss['I'+age_group].iloc[phase], label='Generated')
    ax[1].legend()
    ax[1].grid(True)
    ax[1].set_title('Infected, age '+ age_group+", "+state_name)

    ax[2].plot(R_data_min_loss['R'+age_group].iloc[phase],label='Original')
    ax[2].plot(R_data_gen_min_loss['R'+age_group].iloc[phase], label='Generated')
    ax[2].legend()
    ax[2].grid(True)
    ax[2].set_title('Recovered, age '+ age_group+", "+state_name)

# %%
param_loss_tr_dict[1]['A_No_int_nn']
# Out:
# [array([[3.64872155e+00, 0.00000000e+00, 5.16841533e-03, 0.00000000e+00],
#         [9.68592219e-01, 1.71262316e+00, 5.52102083e-01, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 7.34223067e+00, 0.00000000e+00],
#         [0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 9.46162467e+00]]),
#  array([[3.66873469, 0.        , 0.        , 0.        ],
#         [0.11199459, 2.06142918, 0.        , 0.        ],
#         [0.92566015, 0.12434019, 6.43548984, 0.        ],
#         [0.5318556 , 0.02128406, 0.        , 8.78338423]]),
#  array([[3.45815637, 0.        , 0.14008692, 0.        ],
#         [0.        , 2.09752478, 0.        , 0.        ],
#         [0.        , 0.05362176, 7.27769994, 0.        ],
#         [0.        , 0.        , 0.2119999 , 9.15859345]]),
#  array([[3.69427667, 0.        , 0.        , 0.        ],
#         [1.12014477, 1.87601293, 0.        , 0.        ],
#         [1.51555789, 0.        , 6.50754392, 0.        ],
#         [0.70626119, 0.        , 0.29163024, 8.19186068]])]

# %%
param_loss_tr_dict[1]['Gamma_nn']
# Out:
# [array([0.96286478, 0.9793137 , 0.98768118, 0.99377169]),
#  array([0.97111864, 0.96539481, 0.96853446, 0.97330737]),
#  array([1.00405062, 1.00910465, 1.0072889 , 1.00607774]),
#  array([0.98566434, 0.98647186, 0.98737554, 0.98792104])]
